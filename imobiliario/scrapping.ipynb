# %% [markdown]
# ## Idealista

# %%
import requests

# %%
agents = ('Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
				'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
				'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
				'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/602.2.14 (KHTML, like Gecko) Version/10.0.1 Safari/602.2.14',
				'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
				'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
				'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.98 Safari/537.36',
				'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36',
				'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36',
				'Mozilla/5.0 (Windows NT 10.0; WOW64; rv:50.0) Gecko/20100101 Firefox/50.0')

# %%
{'User-Agent': agents[0]}
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36'}

# %%
av_novas = "https://www.idealista.pt/comprar-casas/lisboa/avenidas-novas/"
page = requests.get(av_novas, headers={'User-Agent': agents[0]})

# %%
page
# Out:
# <Response [403]>

# %%
page.text
# Out:
# '<html><head><title>idealista.pt</title><style>#cmsg{animation: A 1.5s;}@keyframes A{0%{opacity:0;}99%{opacity:0;}100%{opacity:1;}}</style></head><body style="margin:0"><p id="cmsg">Please enable JS and disable any ad blocker</p><script data-cfasync="false">var dd={\'rt\':\'c\',\'cid\':\'AHrlqAAAAAMAKoWQKNWDniAAXj-v0g==\',\'hsh\':\'AC81AADC3279CA4C7B968B717FBB30\',\'t\':\'fe\',\'s\':17156,\'e\':\'a9160cd1ba47312932456fa421c5e60d9b228aa8d5fc9e36624da86f13570307\',\'host\':\'geo.captcha-delivery.com\'}</script><script data-cfasync="false" src="https://ct.captcha-delivery.com/c.js"></script></body></html>\n'

# %%
import undetected_chromedriver as uc

driver = uc.Chrome()

# %%
driver.get(av_novas)

# %%
from selenium.webdriver.common.by import By

# %%
content = driver.find_element(By.ID, "main-header")

# %%
content = driver.find_element(By.CSS_SELECTOR, "section.items-container")

# %%
content.text
# Out:
# '1/\n39\nTop\nApartamento T3 na avenida Elias Garcia, Campo Pequeno - Praça de Espanha, Avenidas Novas\n780.000€\nT3 147 m² área bruta 1º andar com elevador\nApartamento T3 para venda a 780 000 € nas Avenidas Novas. Seja bem vindo/a a este bonito apartamento para remodelar a seu gosto no ce...\nVer telefone\nContactar\nApartamento T4 situado nas Avenidas Novas, Lisboa\n1/\n36\nTop\nApartamento T4 em Campo Pequeno - Praça de Espanha, Avenidas Novas\n875.000€\n980.000 € 11%\nT4 146 m² área bruta 1º andar com elevador\nApartamento T4 em excelente estado de conservação, em plena Avenidas Novas. Situado perto aos jardins da Gulbenkian e do Campo Pequeno,...\nVer telefone\nContactar\nT3 Art Nouveau do início do Sec. XX – Prestígio e Requinte.\n1/\n41\nTop\nApartamento T3 na avenida da República, Entrecampos, Avenidas Novas\n1.160.000€\nT3 175 m² área bruta sem elevador\nSe está à procura de um apartamento ícone no centro de Lisboa, então está a ver o imovel certo! O edifício é um clássico 
# ...

# %%
link = content.find_element(By.TAG_NAME, 'article').find_element(By.CSS_SELECTOR, 'a.item-link')
link.get_attribute('href')
# Out:
# 'https://www.idealista.pt/imovel/32261396/'

# %%
content.find_element(By.TAG_NAME, 'article').get_attribute('data-adid')
# Out:
# '32261396'

# %%
content.find_elements(By.TAG_NAME, 'article')
# Out:
# [<undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="06fff651-79be-4b56-843d-9a46d55c0b03")>,
#  <undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="5d029027-cc89-4746-8b6e-08fba295ea0a")>,
#  <undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="e73e36e8-003b-43d9-be1b-282718b54c4c")>,
#  <undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="57ac4552-38c8-46ce-ba4c-263813b71add")>,
#  <undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="9661bdd9-b2b9-4eba-9ad8-742653a8f519")>,
#  <undetected_chromedriver.webelement.WebElement (session="e470d05677afbbc3d47742dde6255419", element="70bab3a6-0b73-4205-9b0a-a14b760822a7")>,
# ...

# %% [markdown]
# ## Super casa

# %%
from bs4 import BeautifulSoup
import requests

# %%
headers = requests.utils.default_headers()

# %%
headers.update({
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0',
})

# %%
test = requests.get("https://supercasa.pt/comprar-casas/lisboa/avenidas-novas", headers = headers)

# %%
soup = BeautifulSoup(test.text, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-currencysymbol="€" lang="pt">
# <head prefix="og:http://ogp.me/ns#">
# <meta charset="utf-8"/>
# <title> Casas e apartamentos em Avenidas Novas, Lisboa, Lisboa - SUPERCASA</title>
# <meta content="#005baa" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/Images/favicon.png?v=ifqCR08f9H18a-P0Xu0_mKNitQ5f5kQ7YH7VZbLtnf8" rel="icon"/>
# <link href="/Images/favicon.ico?v=TGA-imE0p3VujH1bWBWOjmVlAXnYOeWOA0ta6NwLWmY" rel="shortcut icon" type="image/x-icon"/>
# <meta content="898 Casas e apartamentos em Avenidas Novas, Lisboa, Lisboa, Comprar a partir de 380.000 euros de particulares e imobiliárias. Anúncios de particulares e de agências imobiliárias." name="description"/>
# <meta content="supercasa.pt" name="author"/>
# <meta content="index,follow" name="robots"/>
# <meta content="index,follow" name="googlebot"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# ...
